# %%
# !pip install pytorch_lightning==0.9.0
# Out:
# Requirement already satisfied: pytorch_lightning==0.9.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/gayane/.local/lib/python3.8/site-packages (from pytorch_lightning==0.9.0) (4.49.0)
# Requirement already satisfied: packaging in /home/gayane/miniconda3/lib/python3.8/site-packages (from pytorch_lightning==0.9.0) (20.9)
# Requirement already satisfied: torch>=1.3 in /home/gayane/miniconda3/lib/python3.8/site-packages (from pytorch_lightning==0.9.0) (1.8.1)
# Requirement already satisfied: numpy>=1.16.4 in /home/gayane/miniconda3/lib/python3.8/site-packages (from pytorch_lightning==0.9.0) (1.20.2)
# Requirement already satisfied: tensorboard==2.2.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (from pytorch_lightning==0.9.0) (2.2.0)
# Requirement already satisfied: PyYAML>=5.1 in /home/gayane/miniconda3/lib/python3.8/site-packages (from pytorch_lightning==0.9.0) (5.4.1)
# Requirement already satisfied: future>=0.17.1 in /home/gayane/miniconda3/lib/python3.8/site-packages (from pytorch_lightning==0.9.0) (0.18.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/gayane/miniconda3/lib/python3.8/site-packages (from packaging->pytorch_lightning==0.9.0) (2.4.7)
# Requirement already satisfied: typing-extensions in /home/gayane/miniconda3/lib/python3.8/site-packages (from torch>=1.3->pytorch_lightning==0.9.0) (3.7.4.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (3.3.4)
# Requirement already satisfied: absl-py>=0.4 in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (0.12.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/gayane/.local/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (2.24.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (1.37.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/gayane/.local/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (1.30.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (0.35.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (50.3.1.post20201107)
# Requirement already satisfied: six>=1.10.0 in /home/gayane/.local/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (1.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (0.4.4)
# Requirement already satisfied: protobuf>=3.6.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (from tensorboard==2.2.0->pytorch_lightning==0.9.0) (3.15.8)
# Requirement already satisfied: idna<3,>=2.5 in /home/gayane/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard==2.2.0->pytorch_lightning==0.9.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/gayane/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard==2.2.0->pytorch_lightning==0.9.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gayane/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard==2.2.0->pytorch_lightning==0.9.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/gayane/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard==2.2.0->pytorch_lightning==0.9.0) (1.25.10)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard==2.2.0->pytorch_lightning==0.9.0) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/gayane/miniconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard==2.2.0->pytorch_lightning==0.9.0) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/gayane/miniconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard==2.2.0->pytorch_lightning==0.9.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.2.0->pytorch_lightning==0.9.0) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/gayane/miniconda3/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard==2.2.0->pytorch_lightning==0.9.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.2.0->pytorch_lightning==0.9.0) (3.1.0)

# %%
# !pip install fasttext
# Out:
# Requirement already satisfied: fasttext in /home/gayane/miniconda3/lib/python3.8/site-packages (0.9.2)
# Requirement already satisfied: numpy in /home/gayane/miniconda3/lib/python3.8/site-packages (from fasttext) (1.20.2)
# Requirement already satisfied: setuptools>=0.7.0 in /home/gayane/miniconda3/lib/python3.8/site-packages (from fasttext) (50.3.1.post20201107)
# Requirement already satisfied: pybind11>=2.2 in /home/gayane/miniconda3/lib/python3.8/site-packages (from fasttext) (2.6.2)

# %%
# !pip install pandas-path
# Out:
# Requirement already satisfied: pandas-path in /home/gayane/miniconda3/lib/python3.8/site-packages (0.3.0)
# Requirement already satisfied: pandas>=0.23 in /home/gayane/miniconda3/lib/python3.8/site-packages (from pandas-path) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/gayane/.local/lib/python3.8/site-packages (from pandas>=0.23->pandas-path) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/gayane/miniconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas-path) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /home/gayane/miniconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas-path) (1.20.2)
# Requirement already satisfied: six>=1.5 in /home/gayane/.local/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-path) (1.15.0)

# %%
# %matplotlib inline

import json
import logging
from pathlib import Path
import random
import tarfile
import tempfile
import warnings
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas_path
from tqdm import tqdm

import torch                    
import torchvision
import fasttext
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # LOADING THE DATA

# %%
data_dir = Path.cwd() / 'meme_data'

img_tar_path = data_dir / "img.zip"
img_path = data_dir / 'img'
train_path = data_dir / "train.jsonl"
dev_path = data_dir / "dev.jsonl"
test_path = data_dir / "test.jsonl"

# Extract images if there is need
if not img_path.exists():
    with zipfile.ZipFile(img_tar_path, 'r') as zip_ref:
        zip_ref.extractall(img_path)
        
train_samples_frame = pd.read_json(train_path, lines=True)
print(train_samples_frame.label.value_counts())
train_samples_frame.head()
# Out:
# 0    5481
# 1    2910
# Name: label, dtype: int64
#       id            img  label  \
# 0  42953  img/42953.png      0
# 1  23058  img/23058.png      0
# 2  13894  img/13894.png      0
# 3  37408  img/37408.png      0
# 4  82403  img/82403.png      0
#
#                                                 text
# 0   its their character not their color that matters
# 1  don't be afraid to love again everyone is not ...
# 2                           putting bows on your pet
# 3  i love everything and everybody! except for sq...
# 4  everybody loves chocolate chip cookies, even h...

# %% [markdown]
# # EXPLORING THE TEXT DATA

# %%
train_samples_frame.text.map(
    lambda text: len(text.split(" "))
).describe()
# Out:
# count    8391.000000
# mean       11.703611
# std         6.876207
# min         1.000000
# 25%         7.000000
# 50%        10.000000
# 75%        15.000000
# max        70.000000
# Name: text, dtype: float64

# %% [markdown]
# # EXPLORING THE IMAGE DATA

# %%
from PIL import Image


images = [
    Image.open(
        data_dir / train_samples_frame.loc[i, "img"]
    ).convert("RGB")
    for i in range(5)
]

for image in images:
    print(image.size)
# Out:
# (265, 400)
# (800, 533)
# (558, 800)
# (693, 800)
# (550, 416)

# %% [markdown]
# # Resize images

# %%
# define a callable image_transform with Compose
image_transform = torchvision.transforms.Compose(
    [
        torchvision.transforms.Resize(size=(224, 224)),
        torchvision.transforms.ToTensor()
    ]
)

# convert the images and prepare for visualization.
tensor_img = torch.stack(
    [image_transform(image) for image in images]
)
grid = torchvision.utils.make_grid(tensor_img)

# plot
plt.rcParams["figure.figsize"] = (20, 5)
plt.axis('off')
_ = plt.imshow(grid.permute(1, 2, 0))

# %% [markdown]
# # BUILDING A MULTIMODAL MODEL

# %% [markdown]
# ### CREATING A MULTIMODAL DATASET

# %%
class HatefulMemesDataset(torch.utils.data.Dataset):
    """Uses jsonl data to preprocess and serve 
    dictionary of multimodal tensors for model input.
    """

    def __init__(
        self,
        data_path,
        img_dir,
        image_transform,
        text_transform,
        balance=False,
        dev_limit=None,
        random_state=0,
    ):

        self.samples_frame = pd.read_json(
            data_path, lines=True
        )
        self.dev_limit = dev_limit
        if balance:
            neg = self.samples_frame[
                self.samples_frame.label.eq(0)
            ]
            pos = self.samples_frame[
                self.samples_frame.label.eq(1)
            ]
            self.samples_frame = pd.concat(
                [
                    neg.sample(
                        pos.shape[0], 
                        random_state=random_state
                    ), 
                    pos
                ]
            )
        if self.dev_limit:
            if self.samples_frame.shape[0] > self.dev_limit:
                self.samples_frame = self.samples_frame.sample(
                    dev_limit, random_state=random_state
                )
        self.samples_frame = self.samples_frame.reset_index(
            drop=True
        )
        self.samples_frame.img = self.samples_frame.apply(
            lambda row: (img_dir / row.img), axis=1
        )
            
        self.image_transform = image_transform
        self.text_transform = text_transform

    def __len__(self):
        """This method is called when you do len(instance) 
        for an instance of this class.
        """
        return len(self.samples_frame)

    def __getitem__(self, idx):
        """This method is called when you do instance[key] 
        for an instance of this class.
        """
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_id = self.samples_frame.loc[idx, "id"]

        image = Image.open(
            self.samples_frame.loc[idx, "img"]
        ).convert("RGB")
        image = self.image_transform(image)

        text = torch.Tensor(
            self.text_transform.get_sentence_vector(
                self.samples_frame.loc[idx, "text"]
            )
        ).squeeze()

        if "label" in self.samples_frame.columns:
            label = torch.Tensor(
                [self.samples_frame.loc[idx, "label"]]
            ).long().squeeze()
            sample = {
                "id": img_id, 
                "image": image, 
                "text": text, 
                "label": label
            }
        else:
            sample = {
                "id": img_id, 
                "image": image, 
                "text": text
            }

        return sample

# %% [markdown]
# ### CREATING A MULTIMODAL MODEL

# %%
class LanguageAndVisionConcat(torch.nn.Module):
    def __init__(
        self,
        num_classes,
        loss_fn,
        language_module,
        vision_module,
        language_feature_dim,
        vision_feature_dim,
        fusion_output_size,
        dropout_p,
        
    ):
        super(LanguageAndVisionConcat, self).__init__()
        self.language_module = language_module
        self.vision_module = vision_module
        self.fusion = torch.nn.Linear(
            in_features=(language_feature_dim + vision_feature_dim), 
            out_features=fusion_output_size
        )
        self.fc = torch.nn.Linear(
            in_features=fusion_output_size, 
            out_features=num_classes
        )
        self.loss_fn = loss_fn
        self.dropout = torch.nn.Dropout(dropout_p)
        
    def forward(self, text, image, label=None):
        text_features = torch.nn.functional.relu(
            self.language_module(text)
        )
        image_features = torch.nn.functional.relu(
            self.vision_module(image)
        )
        combined = torch.cat(
            [text_features, image_features], dim=1
        )
        fused = self.dropout(
            torch.nn.functional.relu(
            self.fusion(combined)
            )
        )
        logits = self.fc(fused)
        pred = torch.nn.functional.softmax(logits)
        loss = (
            self.loss_fn(pred, label) 
            if label is not None else label
        )
        return (pred, loss)

# %% [markdown]
# ### TRAINING A MULTIMODAL MODEL

# %%
import pytorch_lightning as pl


# for the purposes of this post, we'll filter
# much of the lovely logging info from our LightningModule
warnings.filterwarnings("ignore")
logging.getLogger().setLevel(logging.WARNING)


class HatefulMemesModel(pl.LightningModule):
    def __init__(self, hparams):
        for data_key in ["train_path", "dev_path", "img_dir",]:
            # ok, there's one for-loop but it doesn't count
            if data_key not in hparams.keys():
                raise KeyError(
                    f"{data_key} is a required hparam in this model"
                )
        
        super(HatefulMemesModel, self).__init__()
        self.hparams = hparams
        
        # assign some hparams that get used in multiple places
        self.embedding_dim = self.hparams.get("embedding_dim", 300)
        self.language_feature_dim = self.hparams.get(
            "language_feature_dim", 300
        )
        self.vision_feature_dim = self.hparams.get(
            # balance language and vision features by default
            "vision_feature_dim", self.language_feature_dim
        )
        self.output_path = Path(
            self.hparams.get("output_path", "model-outputs")
        )
        self.output_path.mkdir(exist_ok=True)
        
        # instantiate transforms, datasets
        self.text_transform = self._build_text_transform()
        self.image_transform = self._build_image_transform()
        self.train_dataset = self._build_dataset("train_path")
        self.dev_dataset = self._build_dataset("dev_path")
        
        # set up model and training
        self.model = self._build_model()
        self.trainer_params = self._get_trainer_params()
    
    ## Required LightningModule Methods (when validating) ##
    
    def forward(self, text, image, label=None):
        return self.model(text, image, label)

    def training_step(self, batch, batch_nb):
        preds, loss = self.forward(
            text=batch["text"], 
            image=batch["image"], 
            label=batch["label"]
        )
        
        return {"loss": loss}

    def validation_step(self, batch, batch_nb):
        preds, loss = self.eval().forward(
            text=batch["text"], 
            image=batch["image"], 
            label=batch["label"]
        )
        
        return {"batch_val_loss": loss}

    def validation_epoch_end(self, outputs):
        avg_loss = torch.stack(
            tuple(
                output["batch_val_loss"] 
                for output in outputs
            )
        ).mean()
        
        return {
            "val_loss": avg_loss,
            "progress_bar":{"avg_val_loss": avg_loss}
        }

    def configure_optimizers(self):
        optimizers = [
            torch.optim.AdamW(
                self.model.parameters(), 
                lr=self.hparams.get("lr", 0.001)
            )
        ]
        schedulers = [
            torch.optim.lr_scheduler.ReduceLROnPlateau(
                optimizers[0]
            )
        ]
        return optimizers, schedulers
    
    def train_dataloader(self):
        return torch.utils.data.DataLoader(
            self.train_dataset, 
            shuffle=True, 
            batch_size=self.hparams.get("batch_size", 4), 
            num_workers=self.hparams.get("num_workers", 16)
        )

    def val_dataloader(self):
        return torch.utils.data.DataLoader(
            self.dev_dataset, 
            shuffle=False, 
            batch_size=self.hparams.get("batch_size", 4), 
            num_workers=self.hparams.get("num_workers", 16)
        )
    
    ## Convenience Methods ##
    
    def fit(self):
        self._set_seed(self.hparams.get("random_state", 42))
        self.trainer = pl.Trainer(**self.trainer_params)
        self.trainer.fit(self)
        
    def _set_seed(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(seed)

    def _build_text_transform(self):
        with tempfile.NamedTemporaryFile() as ft_training_data:
            ft_path = Path(ft_training_data.name)
            with ft_path.open("w") as ft:
                training_data = [
                    json.loads(line)["text"] + "/n" 
                    for line in open(
                        self.hparams.get("train_path")
                    ).read().splitlines()
                ]
                for line in training_data:
                    ft.write(line + "\n")
                language_transform = fasttext.train_unsupervised(
                    str(ft_path),
                    model=self.hparams.get("fasttext_model", "cbow"),
                    dim=self.embedding_dim
                )
        return language_transform
    
    def _build_image_transform(self):
        image_dim = self.hparams.get("image_dim", 224)
        image_transform = torchvision.transforms.Compose(
            [
                torchvision.transforms.Resize(
                    size=(image_dim, image_dim)
                ),        
                torchvision.transforms.ToTensor(),
                # all torchvision models expect the same
                # normalization mean and std
                # https://pytorch.org/docs/stable/torchvision/models.html
                torchvision.transforms.Normalize(
                    mean=(0.485, 0.456, 0.406), 
                    std=(0.229, 0.224, 0.225)
                ),
            ]
        )
        return image_transform

    def _build_dataset(self, dataset_key):
        return HatefulMemesDataset(
            data_path=self.hparams.get(dataset_key, dataset_key),
            img_dir=self.hparams.get("img_dir"),
            image_transform=self.image_transform,
            text_transform=self.text_transform,
            # limit training samples only
            dev_limit=(
                self.hparams.get("dev_limit", None) 
                if "train" in str(dataset_key) else None
            ),
            balance=True if "train" in str(dataset_key) else False,
        )
    
    def _build_model(self):
        # we're going to pass the outputs of our text
        # transform through an additional trainable layer
        # rather than fine-tuning the transform
        language_module = torch.nn.Linear(
                in_features=self.embedding_dim,
                out_features=self.language_feature_dim
        )
        
        # easiest way to get features rather than
        # classification is to overwrite last layer
        # with an identity transformation, we'll reduce
        # dimension using a Linear layer, resnet is 2048 out
        vision_module = torchvision.models.resnet152(
            pretrained=True
        )
        vision_module.fc = torch.nn.Linear(
                in_features=2048,
                out_features=self.vision_feature_dim
        )

        return LanguageAndVisionConcat(
            num_classes=self.hparams.get("num_classes", 2),
            loss_fn=torch.nn.CrossEntropyLoss(),
            language_module=language_module,
            vision_module=vision_module,
            language_feature_dim=self.language_feature_dim,
            vision_feature_dim=self.vision_feature_dim,
            fusion_output_size=self.hparams.get(
                "fusion_output_size", 512
            ),
            dropout_p=self.hparams.get("dropout_p", 0.1),
        )
    
    def _get_trainer_params(self):
        checkpoint_callback = pl.callbacks.ModelCheckpoint(
            filepath=self.output_path,
            monitor=self.hparams.get(
                "checkpoint_monitor", "avg_val_loss"
            ),
            mode=self.hparams.get(
                "checkpoint_monitor_mode", "min"
            ),
            verbose=self.hparams.get("verbose", True)
        )

        early_stop_callback = pl.callbacks.EarlyStopping(
            monitor=self.hparams.get(
                "early_stop_monitor", "avg_val_loss"
            ),
            min_delta=self.hparams.get(
                "early_stop_min_delta", 0.001
            ),
            patience=self.hparams.get(
                "early_stop_patience", 3
            ),
            verbose=self.hparams.get("verbose", True),
        )

        trainer_params = {
            "checkpoint_callback": checkpoint_callback,
            "early_stop_callback": early_stop_callback,
            "weights_save_path": self.output_path,
            "accumulate_grad_batches": self.hparams.get(
                "accumulate_grad_batches", 1
            ),
#             "gpus": self.hparams.get("n_gpu", 1),
            "max_epochs": self.hparams.get("max_epochs", 100),
            "gradient_clip_val": self.hparams.get(
                "gradient_clip_value", 1
            ),
        }
        return trainer_params
            
    @torch.no_grad()
    def make_submission_frame(self, test_path):
        test_dataset = self._build_dataset(test_path)
        submission_frame = pd.DataFrame(
            index=test_dataset.samples_frame.id,
            columns=["proba", "label"]
        )
        test_dataloader = torch.utils.data.DataLoader(
            test_dataset, 
            shuffle=False, 
            batch_size=self.hparams.get("batch_size", 4), 
            num_workers=self.hparams.get("num_workers", 16))
        for batch in tqdm(test_dataloader, total=len(test_dataloader)):
            preds, _ = self.model.eval().to("cpu")(
                batch["text"], batch["image"]
            )
            submission_frame.loc[batch["id"], "proba"] = preds[:, 1]
            submission_frame.loc[batch["id"], "label"] = preds.argmax(dim=1)
        submission_frame.proba = submission_frame.proba.astype(float)
        submission_frame.label = submission_frame.label.astype(int)
        return submission_frame

# %%
hparams = {
    
    # Required hparams
    "train_path": train_path,
    "dev_path": dev_path,
    "img_dir": data_dir,
    
    # Optional hparams
    "embedding_dim": 150,
    "language_feature_dim": 300,
    "vision_feature_dim": 300,
    "fusion_output_size": 256,
    "output_path": "model-outputs",
    "dev_limit": None,
    "lr": 0.00005,
    "max_epochs": 5,
    "n_gpu": 1,
    "batch_size": 4,
    # allows us to "simulate" having larger batches 
    "accumulate_grad_batches": 16,
    "early_stop_patience": 3,
}

hateful_memes_model = HatefulMemesModel(hparams=hparams)
hateful_memes_model.fit()
# Out:
# EarlyStopping mode auto is unknown, fallback to auto mode.
# EarlyStopping mode set to min for monitoring avg_val_loss.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name  | Type                    | Params
# --------------------------------------------------
# 0 | model | LanguageAndVisionConcat | 58 M
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Epoch 00000: avg_val_loss reached 0.65891 (best 0.65891), saving model to model-outputs/epoch=0_v0.ckpt as top 1
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Epoch 00001: avg_val_loss  was not in top 1
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Epoch 00002: avg_val_loss reached 0.63498 (best 0.63498), saving model to model-outputs/epoch=2.ckpt as top 1
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Epoch 00003: avg_val_loss  was not in top 1
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Epoch 00004: avg_val_loss  was not in top 1
# Saving latest checkpoint..

# %%
hparams = {
    
    # Required hparams
    "train_path": train_path,
    "dev_path": dev_path,
    "img_dir": data_dir,
    
    # Optional hparams
    "embedding_dim": 150,
    "language_feature_dim": 300,
    "vision_feature_dim": 300,
    "fusion_output_size": 256,
    "output_path": "model-outputs",
    "dev_limit": None,
    "lr": 0.00005,
    "max_epochs": 5,
    "n_gpu": 1,
    "batch_size": 4,
    # allows us to "simulate" having larger batches 
    "accumulate_grad_batches": 16,
    "early_stop_patience": 3,
}

# %%
hateful_memes_model_m = HatefulMemesModel(hparams=hparams)
hateful_memes_model_m.load_state_dict(torch.load('/home/gayane/Desktop/ACA_ML/hateful-memes-group8/saved_models/pl_model.txt'))
# Out:
# EarlyStopping mode auto is unknown, fallback to auto mode.
# EarlyStopping mode set to min for monitoring avg_val_loss.
# <All keys matched successfully>

# %%
torch.save(hateful_memes_model.state_dict(), '/home/gayane/Desktop/ACA_ML/hateful-memes-group8/saved_models/pl_model.txt')
hateful_memes_model.state_dict()
# Out:
# OrderedDict([('model.language_module.weight',
#               tensor([[ 0.0343,  0.0203,  0.0032,  ..., -0.0234,  0.0488, -0.0735],
#                       [ 0.0223, -0.0803, -0.0552,  ..., -0.0219, -0.0083, -0.0447],
#                       [-0.0612,  0.0749, -0.0778,  ..., -0.0280,  0.0677, -0.0587],
#                       ...,
#                       [ 0.0514,  0.0114,  0.0336,  ..., -0.0527,  0.0530, -0.0169],
#                       [ 0.0031, -0.0099, -0.0034,  ...,  0.0108,  0.0135, -0.0311],
#                       [ 0.0078,  0.0394,  0.0683,  ...,  0.0649,  0.0263, -0.0493]])),
#              ('model.language_module.bias',
#               tensor([ 8.0337e-02,  2.1076e-02, -3.1809e-02,  7.0723e-02,  1.2633e-02,
#                        6.2224e-02, -9.1869e-03, -4.5316e-02, -4.1675e-02, -4.6012e-02,
#                       -8.1453e-02,  6.3037e-02, -8.9551e-03, -6.9241e-02,  1.3316e-02,
#                        5.7380e-02,  1.7760e-02,  2.2683e-02, -6.2041e-02,  6.8016e-02,
#                        5.7434e-02, -6.8326e-02, -5.6827e-02,  4.7617e-03, -5.8853e-02,
#                        5.1387e-02,  2.0045e-02, -5.1289e-02, -7.1806e-02, -3.0357e-02,
#                        8.1123e-02, -3.7198e-02, -3.8624e-02, -1.3694e-02, -7.7768e-02,
#                        4.6146e-02,  1.2568e-02, -5.1625e-02,  6.4921e-02,  4.4568e-02,
#                       -3.0066e-02,  1.2822e-02, -3.5808e-02,  2.7772e-02,  2.5058e-02,
#                       -7.2408e-02,  4.0036e-04,  6.7289e-02,  6.1523e-02,  5.8309e-03,
#                        6.5363e-02,  7.6391e-02,  3.1956e-02, -1.8211e-02,  3.8714e-03,
#                       -3.4930e-02,  7.3978e-02,  7.6300e-03,  3.6665e-02, -1.1170e-03,
#               tensor([[[[-1.7027e-08]],
#
#                        [[-3.1753e-08]],
#
#                        [[ 7.0759e-08]],
#
#                        ...,
#
#                        [[-1.0456e-07]],
#
#                        [[ 2.9827e-08]],
#
#                        [[-2.1292e-08]]],
#
#
#                       [[[-3.3306e-09]],
#
#                        [[ 2.4899e-02]],
#
#                        [[-2.9803e-09]],
#
#                        ...,
#
#                        [[-9.7643e-03]],
#
#                        [[ 3.1986e-03]],
#
#                        [[-3.9125e-01]]],
#
#
#                       [[[ 1.6898e-08]],
#
#                        [[-2.1663e-02]],
#
#                        [[-4.4691e-08]],
#
#                        ...,
#
#                        [[ 9.2537e-02]],
#
#                        [[-5.8080e-02]],
#
#                        [[-8.3571e-02]]],
#
#
#                       ...,
#
#
#                       [[[ 6.7929e-09]],
#
#                        [[ 3.6996e-10]],
#
#                        [[-5.4994e-08]],
#
#                        ...,
#
#                        [[ 1.1402e-08]],
#
#                        [[-5.3047e-08]],
#
#                        [[ 5.7925e-08]]],
#
#
#                       [[[-1.4090e-08]],
#
#                        [[ 2.9231e-08]],
#
#                        [[-2.7279e-08]],
#
#                        ...,
#
#                        [[-1.1071e-08]],
#
#                        [[ 5.5552e-09]],
#
#                        [[ 2.6831e-08]]],
#
#
#                       [[[-1.6641e-08]],
#
#                        [[ 2.5799e-02]],
#
#                        [[ 2.7370e-08]],
#
#                        ...,
#
#                        [[ 1.6554e-02]],
#
#                        [[ 4.7581e-02]],
#
#                        [[-1.4073e-01]]]])),
#              ('model.vision_module.layer1.0.bn1.weight',
#               tensor([ 8.5954e-09,  3.8167e-01,  1.8929e-01,  9.9029e-02,  2.3801e-01,
#                        9.9078e-02,  2.0055e-01,  1.6040e-01,  1.3209e-01, -1.2581e-08,
#                        1.1443e-01,  2.3528e-01,  2.7505e-01,  1.2132e-01,  2.3102e-01,
#                        1.6441e-01,  3.1893e-01,  2.4857e-01,  1.3255e-01,  2.0389e-01,
#                        2.0905e-01,  2.3994e-08,  1.9122e-01,  3.4904e-01,  2.3834e-01,
#                        2.0059e-01,  2.0439e-01,  3.0090e-01,  2.6439e-08,  2.4708e-01,
#                        4.6004e-02,  2.2383e-01,  2.8930e-09,  7.2399e-09,  1.4294e-08,
#                        1.7155e-09,  2.8907e-01,  1.8357e-01,  1.0772e-01,  4.6958e-09,
#                        2.1890e-01,  1.9979e-01,  1.2738e-01,  3.1190e-02,  5.2922e-09,
#                        1.2617e-01,  2.3782e-01,  4.8414e-08,  7.4850e-09,  1.0813e-01,
#                        1.5443e-01,  3.2880e-09,  1.6156e-08,  1.7075e-01,  3.6553e-08,
#                        1.5473e-01,  1.3252e-01,  2.3338e-01,  1.4643e-08,  9.9811e-09,
#                        5.1730e-09,  1.7728e-09,  2.6805e-08,  2.8427e-01])),
#              ('model.vision_module.layer1.0.bn1.bias',
#               tensor([-3.9394e-08, -1.1359e-01,  3.8128e-01,  2.3170e-01, -6.1311e-02,
#                        1.1284e-01, -3.1391e-01,  2.0831e-01,  3.2000e-01, -2.8276e-08,
#                        8.0110e-02,  3.5600e-02, -6.8442e-02, -5.7947e-02,  4.9749e-01,
#                       2.4821e-02, 3.2312e-04, 7.2825e-15, 2.2077e-02, 5.0654e-02, 1.7480e-14,
#                       9.6992e-15, 4.5601e-03, 1.0995e-01, 5.6880e-16, 1.2108e-14, 1.8336e-02,
#                       1.7407e-14, 1.8029e-02, 1.6121e-02, 3.0242e-02, 4.2153e-15, 3.6826e-15,
#                       6.8870e-15, 1.8886e-15, 1.4661e-14, 7.0811e-02])),
#              ('model.vision_module.layer1.0.bn1.num_batches_tracked',
#               tensor(7275)),
#              ('model.vision_module.layer1.0.conv2.weight',
#               tensor([[[[-8.0467e-09,  2.6906e-08,  1.3910e-09],
#                         [ 1.6528e-08,  3.1728e-08, -1.2548e-08],
#                         [ 1.4098e-09,  2.0414e-08,  1.3466e-08]],
#
#                        [[-1.4841e-02,  9.3917e-03, -3.7121e-02],
#                         [-2.4753e-04,  1.1285e-01,  1.5277e-02],
#                         [-2.5584e-02,  3.0212e-02,  2.3436e-02]],
#
#                        [[ 1.7597e-03,  7.8912e-03,  1.3899e-02],
#                         [-2.1245e-02,  3.6693e-02,  6.8416e-02],
#                         [-3.2567e-02,  1.4618e-02,  2.8517e-02]],
#
#                        ...,
#
#                        [[-2.3655e-08, -1.8492e-08, -2.2867e-08],
#                         [-1.5148e-08, -1.7440e-08, -2.7765e-08],
#                         [-1.9133e-08, -2.4358e-08, -3.0104e-08]],
#
#                        [[ 1.6907e-08, -8.6781e-09,  2.5681e-08],
#                         [ 3.0702e-09,  1.3370e-09,  4.6289e-09],
#                         [-3.0390e-09, -9.6617e-09, -1.9121e-08]],
#
#                        [[-2.7308e-02,  1.7462e-02, -3.6107e-02],
#                         [ 9.9337e-03,  1.6988e-01,  2.5513e-02],
#                         [-3.1724e-02,  3.1115e-02, -1.3893e-02]]],
#
#
#                       [[[ 6.3968e-10,  2.4852e-08, -9.5719e-09],
#                         [ 3.7542e-08,  4.8426e-08,  3.7734e-08],
#                         [ 3.5947e-08,  3.2310e-08,  6.0110e-08]],
#
#                        [[-9.9418e-03,  1.9418e-02, -1.9922e-03],
#                         [-1.8816e-02,  3.2846e-02,  1.3728e-02],
#                         [ 7.7279e-03, -6.3879e-04,  1.5100e-03]],
#
#                        [[ 6.8685e-02,  8.1167e-02,  7.5836e-02],
#                         [ 2.5515e-02, -1.1868e-01, -4.1831e-05],
#                         [ 5.2145e-02, -7.5035e-03,  6.5397e-02]],
#
#                        ...,
#
#                        [[-5.5678e-09,  9.9716e-09, -4.3815e-09],
#                         [-1.0587e-08,  2.3022e-08,  1.0467e-08],
#                         [ 1.1019e-08,  6.4692e-09, -4.7036e-09]],
#
#                        [[ 3.2727e-08, -2.3587e-09, -1.2578e-08],
#                         [ 1.2646e-08, -3.0255e-09, -7.3339e-09],
#                         [ 4.0226e-08,  3.1769e-08, -9.5032e-10]],
#
#                        [[-6.0688e-03, -5.1800e-02,  1.5309e-02],
#                         [-1.2447e-02, -9.5513e-02,  2.2444e-02],
#                         [ 1.0882e-02, -6.6371e-02, -4.7233e-03]]],
#
#
#                       2.2048e-03, 1.5447e-02, 8.5294e-03, 1.1131e-02, 3.7212e-02, 7.0213e-03,
#                       6.3412e-14, 7.0192e-03, 7.1192e-02, 3.0528e-02, 7.1646e-02, 8.8158e-03,
#                       1.2215e-02, 1.1305e-02, 4.8798e-02, 2.4878e-15, 4.2918e-02, 1.2893e-14,
#                       6.0436e-03, 1.0734e-02, 3.8008e-02, 4.8308e-02, 2.6009e-02, 3.3920e-02,
#                       1.0942e-04, 8.0644e-03, 6.2785e-03, 7.9990e-03, 4.7742e-02, 8.1392e-03,
#                       7.9853e-15, 1.1587e-01, 6.5184e-02, 1.0117e-02, 2.6178e-02, 4.0296e-02,
#                       1.0391e-01, 9.5187e-02, 5.1862e-02, 1.2690e-01])),
#              ('model.vision_module.layer1.0.bn2.num_batches_tracked',
#               tensor(7275)),
#              ('model.vision_module.layer1.0.conv3.weight',
#               tensor([[[[ 5.4858e-06]],
#
#                        [[-4.4831e-07]],
#
#                        [[ 3.1782e-06]],
#
#                        ...,
#
#                        [[-5.7020e-06]],
#
#                        [[ 6.3215e-06]],
#
#                        [[-2.5358e-06]]],
#
#
#                       [[[ 8.2467e-04]],
#
#                        [[-3.4663e-02]],
#
#                        [[-3.1346e-03]],
#
#                        ...,
#
#                        [[-2.1663e-02]],
#
#                        [[-3.4851e-02]],
#
#                        [[ 4.8607e-03]]],
#
#
#                       [[[ 1.1265e-04]],
#
#                        [[ 2.7932e-04]],
#
#                        [[ 1.0793e-05]],
#
#                        ...,
#
#                        [[ 6.4891e-04]],
#
#                        [[-4.3420e-04]],
#
#                        [[-3.5619e-04]]],
#
#
#                       ...,
#
#
#                       [[[-7.9329e-03]],
#
#                        [[-5.4902e-03]],
#
#                        [[ 7.1410e-02]],
#
#                        ...,
#
#                        [[ 1.0600e-01]],
#
#                        [[ 9.2596e-02]],
#
#                        [[ 1.4756e-02]]],
#
#
#                       [[[-2.4712e-02]],
#
#                        [[ 2.8054e-02]],
#
#                        [[-1.7860e-01]],
#
#                        ...,
#
#                        [[ 1.0946e-02]],
#
#                        [[ 1.6075e-02]],
#
#                        [[ 2.7804e-02]]],
#
# ...
#               tensor(7275)),
#              ('model.vision_module.fc.weight',
#               tensor([[ 1.0673e-02,  3.8956e-04, -1.8229e-02,  ...,  2.2256e-02,
#                        -1.6646e-02, -1.8557e-04],
#                       [ 2.2198e-02,  1.8397e-02,  8.3861e-03,  ..., -1.5408e-02,
#                        -1.6486e-02,  2.5713e-03],
#                       [ 2.1835e-02,  2.3777e-03,  1.2370e-02,  ...,  5.2664e-05,
#                        -6.4548e-03,  8.0742e-03],
#                       ...,
#                       [ 1.7418e-02,  1.5107e-02, -1.9088e-02,  ...,  1.2407e-02,
#                        -2.1305e-02,  7.2365e-03],
#                       [ 1.4615e-02, -9.5270e-03,  1.5693e-03,  ...,  2.0014e-02,
#                         2.0486e-04, -3.5457e-03],
#                       [-5.8107e-03, -1.1412e-02,  1.7921e-02,  ..., -2.5669e-03,
#                         1.7829e-02,  1.7136e-03]])),
#                         0.0437, -0.0044, -0.0523,  0.0069, -0.0653, -0.0220,  0.0445, -0.0567,
#                        -0.0442, -0.0334, -0.0259,  0.0093,  0.0099, -0.0486,  0.0002, -0.0199,
#                         0.0618, -0.0257, -0.0651, -0.0431,  0.0547, -0.0271, -0.0239,  0.0427,
#                         0.0302, -0.0184,  0.0298,  0.0263,  0.0473, -0.0496, -0.0630,  0.0123,
#                         0.0318,  0.0142,  0.0258, -0.0104,  0.0556, -0.0141, -0.0627, -0.0234,
#                        -0.0246,  0.0491, -0.0436, -0.0068,  0.0283, -0.0243,  0.0261,  0.0286,
#                         0.0024,  0.0141,  0.0435,  0.0227,  0.0455, -0.0274,  0.0156,  0.0643,
#                        -0.0157,  0.0583,  0.0517,  0.0500, -0.0298, -0.0563,  0.0253,  0.0539,
#                        -0.0274,  0.0320,  0.0519,  0.0095,  0.0538,  0.0144,  0.0330,  0.0310]])),
#              ('model.fc.bias', tensor([-0.0149, -0.0323]))])

# %%
submission = hateful_memes_model_m.make_submission_frame(
    dev_path
)
# Out:
# 100%|██████████| 28/28 [00:44<00:00,  1.58s/it]

# %%
submission.label.value_counts()
# Out:
# 0    63
# 1    46
# Name: label, dtype: int64

# %%
submission.to_csv(("model-outputs/submission.csv"), index=True)

# %%
probabilities = submission.proba
predicted = []
really = []
actualy = {}
threshold = 0.5

# %%
test_data = {}
with open(dev_path) as f:
    for data in f:
        actualy[json.loads(data)['id']] = json.loads(data)['label']

# %%
for id, proba in probabilities.items():
    act_pro = actualy.get('id', 0)
    if act_pro != None:
        predicted.append(0 if proba < threshold else 1)
        really.append(act_pro)

# %%
from sklearn.metrics import accuracy_score, roc_auc_score


def get_metrics(y_pred, y_true):
    metrics = {
        'accuracy': accuracy_score(y_true, y_pred),
        'roc_auc_score': roc_auc_score(y_true, y_pred)
    }
    return metrics
    
get_metrics(really, predicted)
# Out:
# {'accuracy': 0.5779816513761468, 'roc_auc_score': 0.5}

# %%
roc_auc_score(predicted, really)
# Out:
# 0.5

# %%
dir(hateful_memes_model_m)
# Out:
# ['CHECKPOINT_HYPER_PARAMS_KEY',
#  'CHECKPOINT_HYPER_PARAMS_NAME',
#  'CHECKPOINT_HYPER_PARAMS_TYPE',
#  'T_destination',
#  '_DeviceDtypeModuleMixin__update_properties',
#  '_LightningModule__get_hparams_assignment_variable',
#  '__abstractmethods__',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply',
#  '_auto_collect_arguments',
#  '_backward_hooks',
#  '_buffers',
#  '_build_dataset',
#  '_build_image_transform',
#  '_build_model',
#  '_build_text_transform',
#  '_call_impl',
#  '_datamodule',
#  '_device',
#  '_dtype',
#  '_example_input_array',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_get_backward_hooks',
#  '_get_name',
#  '_get_trainer_params',
#  '_hparams',
#  '_hparams_name',
#  '_init_slurm_connection',
#  '_is_full_backward_hook',
#  '_load_from_state_dict',
#  '_load_model_state',
#  '_load_state_dict_pre_hooks',
#  '_maybe_warn_non_full_backward_hook',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_parameters',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_replicate_for_data_parallel',
#  '_save_to_state_dict',
#  '_set_hparams',
#  '_set_seed',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_version',
#  'add_module',
#  'amp_scale_loss',
#  'apply',
#  'backward',
#  'bfloat16',
#  'buffers',
#  'children',
#  'configure_apex',
#  'configure_ddp',
#  'configure_optimizers',
#  'configure_sync_batchnorm',
#  'cpu',
#  'cuda',
#  'current_epoch',
#  'datamodule',
#  'dev_dataset',
#  'device',
#  'double',
#  'dtype',
#  'dump_patches',
#  'embedding_dim',
#  'eval',
#  'example_input_array',
#  'exp_save_path',
#  'extra_repr',
#  'fit',
#  'float',
#  'forward',
#  'freeze',
#  'get_progress_bar_dict',
#  'get_tqdm_dict',
#  'global_step',
#  'grad_norm',
#  'half',
#  'hparams',
#  'image_transform',
#  'init_ddp_connection',
#  'language_feature_dim',
#  'load_from_checkpoint',
#  'load_state_dict',
#  'loaded_optimizer_states_dict',
#  'logger',
#  'make_submission_frame',
#  'model',
#  'modules',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'on_after_backward',
#  'on_batch_end',
#  'on_batch_start',
#  'on_before_zero_grad',
#  'on_epoch_end',
#  'on_epoch_start',
#  'on_fit_end',
#  'on_fit_start',
#  'on_gpu',
#  'on_hpc_load',
#  'on_hpc_save',
#  'on_load_checkpoint',
#  'on_post_performance_check',
#  'on_pre_performance_check',
#  'on_pretrain_routine_end',
#  'on_pretrain_routine_start',
#  'on_save_checkpoint',
#  'on_test_batch_end',
#  'on_test_batch_start',
#  'on_test_epoch_end',
#  'on_test_epoch_start',
#  'on_train_batch_end',
#  'on_train_batch_start',
#  'on_train_end',
#  'on_train_epoch_end',
#  'on_train_epoch_start',
#  'on_train_start',
#  'on_validation_batch_end',
#  'on_validation_batch_start',
#  'on_validation_epoch_end',
#  'on_validation_epoch_start',
#  'optimizer_step',
#  'optimizer_zero_grad',
#  'output_path',
#  'parameters',
#  'precision',
#  'prepare_data',
#  'print',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_full_backward_hook',
#  'register_parameter',
#  'requires_grad_',
#  'save_hyperparameters',
#  'setup',
#  'share_memory',
#  'state_dict',
#  'summarize',
#  'tbptt_split_batch',
#  'teardown',
#  'test_dataloader',
#  'test_end',
#  'test_epoch_end',
#  'test_step',
#  'test_step_end',
#  'text_transform',
#  'tng_dataloader',
#  'to',
#  'to_onnx',
#  'train',
#  'train_dataloader',
#  'train_dataset',
#  'trainer',
#  'trainer_params',
#  'training',
#  'training_end',
#  'training_epoch_end',
#  'training_step',
#  'training_step_end',
#  'transfer_batch_to_device',
#  'type',
#  'unfreeze',
#  'use_amp',
#  'use_ddp',
#  'use_ddp2',
#  'use_dp',
#  'use_tpu',
#  'val_dataloader',
#  'validation_end',
#  'validation_epoch_end',
#  'validation_step',
#  'validation_step_end',
#  'vision_feature_dim',
#  'xpu',
#  'zero_grad']
